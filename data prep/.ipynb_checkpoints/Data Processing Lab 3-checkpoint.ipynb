# %%
import pandas as pd
import numpy as np

# %%
articles = pd.read_csv('article.csv', sep=';')
proceeding = pd.read_csv('proceeding_papers.csv', sep=';')

# %%
articles.head()
# Out:
#    article                                        author         author-orcid  \
# 0   884424  Andrew Nealen|Johannes Zimmermann|Marc Alexa                  NaN
# 1  1066027                  Hyeonjoon Moon|Kanghun Jeong                  NaN
# 2  2730573              Ramesh Chandra|Vaibhav Bhatnagar                  NaN
# 3  2266697                              Emin Islam Tatli  0000-0003-4562-8486
# 4   174388                                  Shawn Bowers                  NaN
#
#                                             ee ee-type  \
# 0    https://doi.org/10.1016/j.cag.2008.05.006     NaN
# 1     https://doi.org/10.3837/tiis.2011.01.013      oa
# 2  https://doi.org/10.1504/IJSCCPS.2019.100197     NaN
# 3    https://doi.org/10.1109/TIFS.2015.2422259     NaN
# 4    https://doi.org/10.1007/s13740-012-0004-y     NaN
#
#                                   journal                          key  \
# 0                          Comput. Graph.   journals/cg/ZimmermannNA08
# ...

# %%
proceeding.head()
# Out:
#    inproceedings                                             author  \
# 0        7043780   Joxe Gaintzarain|Marisa Navarro|Montserrat Hermo
# 1        7043780   Joxe Gaintzarain|Marisa Navarro|Montserrat Hermo
# 2        7043780   Joxe Gaintzarain|Marisa Navarro|Montserrat Hermo
# 3        7043780   Joxe Gaintzarain|Marisa Navarro|Montserrat Hermo
# 4        7042963  Daniël Paulusma|Giacomo Paesani|Konrad K. Dabr...
#
#                               author-orcid booktitle        crossref  \
# 0  0000-0001-5627-501X|0000-0001-9768-9964      MFCS  conf/mfcs/2005
# 1  0000-0001-5627-501X|0000-0001-9768-9964      MFCS  conf/mfcs/2005
# 2  0000-0001-5627-501X|0000-0001-9768-9964      MFCS  conf/mfcs/2005
# 3  0000-0001-5627-501X|0000-0001-9768-9964      MFCS  conf/mfcs/2005
# 4  0000-0001-5945-9287|0000-0002-7295-2663      MFCS  conf/mfcs/2018
#
#                                       inprocee ee-type  \
# 0          https://doi.org/10.1007/11549345_33     NaN
# ...
